# %%
import pandas as pd

df = pd.read_csv('../data/hotel_processed.csv')
df.head()
# Out:
#        hotel_id                                               name  \
# 0  hotel_000000              HoLo Kim Ma Hanoi - Serviced Homestay
# 1  hotel_000001                               Sheraton Hanoi Hotel
# 2  hotel_000002  Luli Homestay - 40m Newly Built House, Luxury ...
# 3  hotel_000003                    Hera Palace Apartment - Ba Đình
# 4  hotel_000004                                  Nam Cường X Hotel
#
#                                                 link       price  \
# 0  https://www.booking.com/hotel/vn/holo-kim-ma-h...    318090.0
# 1  https://www.booking.com/hotel/vn/sheraton-hano...  12400000.0
# 2  https://www.booking.com/hotel/vn/luli-homestay...    390000.0
# 3  https://www.booking.com/hotel/vn/hera-palace-a...    337500.0
# 4  https://www.booking.com/hotel/vn/nam-cuong-x-c...    324000.0
#
#                      tax_info  rating                location  \
# 0      Đã bao gồm thuế và phí    8.68  Quận Ba Đình, Hà Nội
# 1  +VND 1.929.440 thuế và phí    8.18   Quận Tây Hồ, Hà Nội
# 2      Đã bao gồm thuế và phí    7.67  Quận Ba Đình, Hà Nội
# 3      Đã bao gồm thuế và phí    7.87  Quận Ba Đình, Hà Nội
# 4      Đã bao gồm thuế và phí    8.38      Cau Giay, Hà Nội
#
#                                          description  \
# 0  Nằm ở Hà Nội, HoLo Kim Ma Hanoi - Serviced H...
# 1  Nằm cách trung tâm thành phố Hà Nội và Hồ Hoàn...
# 2  Với khu vườn và sân hiên, Luli Homestay - 40m ...
# 3  Nằm ở Hà Nội, cách Trung tâm thương mại Vinc...
# 4  Tọa lạc ở Hà Nội, cách Bảo tàng dân tộc học ...
#
#                                               images  \
# 0  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 1  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 2  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 3  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 4  [{'url': 'https://cf.bstatic.com/xdata/images/...
#
#                                           room_types   city  elderly_friendly  \
# 0  [{'name': 'Phòng Giường Đôi', 'bed_type': 'N/A...  hanoi             False
# 1  [{'name': 'Phòng Sheraton Club Có Giường Cỡ Ki...  hanoi             False
# 2  [{'name': 'Phòng Superior Có Giường Cỡ King', ...  hanoi             False
# 3  [{'name': 'Phòng Superior Giường Đôi', 'bed_ty...  hanoi             False
# 4  [{'name': 'Phòng Superior Giường Đôi', 'bed_ty...  hanoi             False
#
#   room_info unit
# 0       NaN  VND
# 1       NaN  VND
# 2       NaN  VND
# 3       NaN  VND
# 4       NaN  VND

# %%
import pandas as pd

df['price'] = df['price'].replace({'VND': '', ',': '', '\xa0': '', '\.': ''}, regex=True)

df['price'] = df['price'].astype(float)

print(df['price'].head())
df
# Out:
# 0    744480.0
# 1    394181.0
# 2    663200.0
# 3    494250.0
# 4    494250.0
# Name: price, dtype: float64
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# /var/folders/8_/99ssssd94jqfq58f6bq_hp_80000gn/T/ipykernel_7769/3088089040.py:3: SyntaxWarning: invalid escape sequence '\.'
#   df['price'] = df['price'].replace({'VND': '', ',': '', '\xa0': '', '\.': ''}, regex=True)
#                                                    name  \
# 0                                      NT Elysian hotel
# 1                            Eco Nest Hotel & Apartment
# 2                                            VVIP Suite
# 3     Apartment 1BR-FL24th-R105 Building-Vinhomes Oc...
# 4     Apartment 1BR-FL22th-R103 Building-Vinhome Oce...
# ...                                                 ...
# 8255           Luxe Paradise Residence Nguyen Khac Hieu
# 8256                       Sunny Days Apartment & Hotel
# 8257                        First Eden Hotel - Hang Bun
# 8258                           The Orchid Luxury Suites
# 8259                                Homestay Long Chiều
#
#                                                    link      price  \
# 0     https://www.booking.com/hotel/vn/nt-elysian.vi...   744480.0
# 1     https://www.booking.com/hotel/vn/eco-nest-amp-...   394181.0
# 2     https://www.booking.com/hotel/vn/vvip-suite.vi...   663200.0
# 3     https://www.booking.com/hotel/vn/1brfl16th-rub...   494250.0
# 4     https://www.booking.com/hotel/vn/1br-fl22th-ru...   494250.0
# ...                                                 ...        ...
# 8255  https://www.booking.com/hotel/vn/luxe-paradise...   540000.0
# 8256  https://www.booking.com/hotel/vn/paradise-home...   600000.0
# 8257  https://www.booking.com/hotel/vn/first-eden.vi...   570000.0
# 8258  https://www.booking.com/hotel/vn/the-orchid-lu...  1350000.0
# 8259  https://www.booking.com/hotel/vn/homestay-long...   292000.0
#
#                     tax_info  rating                  location  \
# 0     Đã bao gồm thuế và phí    9.39  Quận Hoàn Kiếm, Hà Nội
# 1     Đã bao gồm thuế và phí    7.47  Quận Hoàn Kiếm, Hà Nội
# 2     Đã bao gồm thuế và phí     NaN    Quận Đống Đa, Hà Nội
# 3     Đã bao gồm thuế và phí    9.79                  Hà Nội
# 4     Đã bao gồm thuế và phí    9.79                  Hà Nội
# ...                      ...     ...                       ...
# 8255  Đã bao gồm thuế và phí    6.86    Quận Ba Đình, Hà Nội
# 8256  Đã bao gồm thuế và phí    8.28    Quận Đống Đa, Hà Nội
# 8257  Đã bao gồm thuế và phí    8.38    Quận Ba Đình, Hà Nội
# 8258  Đã bao gồm thuế và phí     NaN        Cau Giay, Hà Nội
# 8259  Đã bao gồm thuế và phí     NaN    Quận Đống Đa, Hà Nội
#
#                                             description  \
# 0     Nằm tại vị trí thuận tiện ở trung tâm Hà Nội...
# 1     Eco Nest Hotel & Apartment cung cấp chỗ nghỉ t...
# 2     Nằm ở Hà Nội, cách Bảo tàng mỹ thuật Việt Na...
# 3     Nằm ở Hà Nội, cách Trung tâm mua sắm AEON MA...
# 4     Tọa lạc ở Hà Nội, cách Trung tâm mua sắm AEO...
# ...                                                 ...
# 8255  Tọa lạc ở Quận Ba Đình, Hà Nội, Luxe Paradis...
# 8256  Tọa lạc ở Hà Nội, cách Ga Hà Nội 12 phút đi ...
# 8257  First Eden Hotel - Hang Bun là chỗ nghỉ 3 sao ...
# 8258  Tọa lạc ở Hà Nội thuộc Hà Nội, The Orchid Lu...
# 8259  Homestay Long Chiều có ban công và tọa lạc ở H...
#
#                                                  images  \
# 0     [{'url': 'https://cf.bstatic.com/xdata/images/...
# 1     [{'url': 'https://cf.bstatic.com/xdata/images/...
# 2     [{'url': 'https://cf.bstatic.com/xdata/images/...
# 3     [{'url': 'https://cf.bstatic.com/xdata/images/...
# 4     [{'url': 'https://cf.bstatic.com/xdata/images/...
# ...                                                 ...
# 8255  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 8256  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 8257  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 8258  [{'url': 'https://cf.bstatic.com/xdata/images/...
# 8259  [{'url': 'https://cf.bstatic.com/xdata/images/...
#
#                                              room_types  elderly_friendly  \
# 0     [{'name': 'Phòng Superior Giường Đôi', 'bed_ty...              True
# 1     [{'name': 'Studio Tiêu Chuẩn', 'bed_type': 'N/...              True
# 2     [{'name': 'Căn Hộ 1 Phòng Ngủ', 'bed_type': 'N...              True
# 3     [{'name': 'Căn Hộ Có Tầm Nhìn Và Ban Công', 'b...              True
# 4     [{'name': 'Căn Hộ Có Ban Công', 'bed_type': 'N...              True
# ...                                                 ...               ...
# 8255  [{'name': 'Căn Hộ Có Ban Công', 'bed_type': 'N...             False
# 8256  [{'name': 'Suite Deluxe', 'bed_type': 'N/A', '...             False
# 8257  [{'name': 'Phòng Superior Giường Đôi/2 Giường ...             False
# 8258  [{'name': 'Căn Hộ 1 Phòng Ngủ', 'bed_type': 'N...             False
# 8259  [{'name': 'Nhà 1 Phòng ngủ', 'bed_type': 'N/A'...             False
#
#         city
# 0     Hà Nội
# 1     Hà Nội
# 2     Hà Nội
# 3     Hà Nội
# 4     Hà Nội
# ...      ...
# 8255  Hà Nội
# 8256  Hà Nội
# 8257  Hà Nội
# 8258  Hà Nội
# 8259  Hà Nội
#
# [8260 rows x 11 columns]

# %%
df['rating'].fillna(df['rating'].mean(), inplace=True)

# %%
from openai import OpenAI
import pandas as pd

# Chọn subset dữ liệu & tạo bản sao để tránh warning
df = df[30:40].copy()

# Thiết lập OpenAI API key
api_key = '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'
client = OpenAI(api_key=api_key)

# Hàm xử lý dạng room_type nếu là list (nếu bạn dùng)
def process_room_type(room_type):
    if isinstance(room_type, list):
        return ', '.join(room_type)
    return room_type

# Hàm lấy embedding từ OpenAI
def get_openai_embeddings(text):
    response = client.embeddings.create(
        input=text,
        model="text-embedding-3-small"
    )
    return response.data[0].embedding

# Tạo context từ description + price + rating
df.loc[:, 'context'] = df.apply(lambda row: f'''
mô tả của khách sạn:
{row['description']}
Giá là {row['price']}
Điểm đánh giá của nó là {row['rating']}
''', axis=1)

# In thử context tạo ra
print(df['context'])

# Tạo embedding cho từng context
df.loc[:, 'context_embedding'] = df['context'].apply(get_openai_embeddings)

# In kết quả
print(df[['name', 'description', 'context_embedding']].head())
# Out:
# 30    \nmô tả của khách sạn:\nTọa lạc ở Hà Nội, cá...
# 31    \nmô tả của khách sạn:\nLa Dolce Vita Hotel có...
# 32    \nmô tả của khách sạn:\nNằm ở Hà Nội, cách T...
# 33    \nmô tả của khách sạn:\nTọa lạc ở Hà Nội, cá...
# 34    \nmô tả của khách sạn:\nTọa lạc ở Hà Nội, cá...
# 35    \nmô tả của khách sạn:\nNằm ở Hà Nội, cách N...
# 36    \nmô tả của khách sạn:\nTọa lạc ở Hà Nội, cá...
# 37    \nmô tả của khách sạn:\nNằm ở Hà Nội, cách S...
# 38    \nmô tả của khách sạn:\nNằm ở Hà Nội, cách B...
# 39    \nmô tả của khách sạn:\nNằm ở Hà Nội, 22Land...
# Name: context, dtype: object
#                                                  name  \
# 30                                  Nam Cường X Hotel
# 31                                La Dolce Vita Hotel
# 32  Apartment 1BR-FL24th-R105 Building-Vinhomes Oc...
# 33  Apartment 1BR-FL22th-R103 Building-Vinhome Oce...
# 34                            Hi.Home House near Lake
#
#                                           description  \
# 30  Tọa lạc ở Hà Nội, cách Bảo tàng dân tộc học ...
# 31  La Dolce Vita Hotel có trung tâm thể dục, phòn...
# 32  Nằm ở Hà Nội, cách Trung tâm mua sắm AEON MA...
# 33  Tọa lạc ở Hà Nội, cách Trung tâm mua sắm AEO...
# 34  Tọa lạc ở Hà Nội, cách Trung tâm thương mại ...
#
#                                     context_embedding
# 30  [0.012199758552014828, -0.014024918898940086, ...
# 31  [-0.010298688896000385, -0.026866145431995392,...
# 32  [-0.013048727065324783, -0.03454648703336716, ...
# 33  [-0.008611531928181648, -0.040776606649160385,...
# 34  [-0.011722579598426819, -0.025251008570194244,...

# %%
df['context'][31]
# Out:
# '\nmô tả của khách sạn:\nLa Dolce Vita Hotel có trung tâm thể dục, phòng chờ chung, nhà hàng và quầy bar ở Hà Nội. Khách sạn 4 sao này có dịch vụ văn phòng và dịch vụ tiền sảnh. Chỗ nghỉ cung cấp lễ tân 24/24, dịch vụ đưa đón sân bay, dịch vụ phòng và Wi-Fi miễn phí ở toàn bộ chỗ nghỉ.\n\nTại khách sạn, tất cả các phòng có điều hòa, khu vực ghế ngồi, TV màn hình phẳng có truyền hình vệ tinh, két an toàn, phòng tắm riêng, vòi sen, đồ vệ sinh cá nhân miễn phí và máy sấy tóc. Tất cả các phòng đều có ấm đun nước, trong đó một số phòng có sân hiên và một số khác thì nhìn ra thành phố. Tất cả các căn đều có tủ lạnh.\n\nLa Dolce Vita Hotel có phục vụ bữa sáng thực đơn buffet.\n\nKhách có thể chơi trò phi tiêu tại chỗ nghỉ. Ngoài ra, chỗ nghỉ có dịch vụ thuê xe đạp và dịch vụ thuê ô tô.\n\nCác điểm tham quan nổi tiếng gần La Dolce Vita Hotel bao gồm Ô Quan Chưởng, Nhà hát múa rối Thăng Long và Hồ Hoàn Kiếm. Sân bay Quốc tế Nội Bài cách 24 km.\nGía là 3091000.0\nĐiểm đánh giá của nó là 7.47\n'

# %%
'\nmô tả của khách sạn:\nLa Dolce Vita Hotel có trung tâm thể dục, phòng chờ chung, nhà hàng và quầy bar ở Hà Nội. Khách sạn 4 sao này có dịch vụ văn phòng và dịch vụ tiền sảnh. Chỗ nghỉ cung cấp lễ tân 24/24, dịch vụ đưa đón sân bay, dịch vụ phòng và Wi-Fi miễn phí ở toàn bộ chỗ nghỉ.\n\nTại khách sạn, tất cả các phòng có điều hòa, khu vực ghế ngồi, TV màn hình phẳng có truyền hình vệ tinh, két an toàn, phòng tắm riêng, vòi sen, đồ vệ sinh cá nhân miễn phí và máy sấy tóc. Tất cả các phòng đều có ấm đun nước, trong đó một số phòng có sân hiên và một số khác thì nhìn ra thành phố. Tất cả các căn đều có tủ lạnh.\n\nLa Dolce Vita Hotel có phục vụ bữa sáng thực đơn buffet.\n\nKhách có thể chơi trò phi tiêu tại chỗ nghỉ. Ngoài ra, chỗ nghỉ có dịch vụ thuê xe đạp và dịch vụ thuê ô tô.\n\nCác điểm tham quan nổi tiếng gần La Dolce Vita Hotel bao gồm Ô Quan Chưởng, Nhà hát múa rối Thăng Long và Hồ Hoàn Kiếm. Sân bay Quốc tế Nội Bài cách 24 km.\nGía là 3091000.0\nĐiểm đánh giá của nó là 7.47\n'

# %%
'\nmô tả của khách sạn:\nNằm ở Hà Nội, cách Nhà hát Lớn Hà Nội 2.2 km, Sunrise Hanoi Hotel cung cấp chỗ nghỉ có phòng chờ chung, chỗ đậu xe riêng miễn phí, sân hiên và nhà hàng. Khách sạn 3 sao này có dịch vụ phòng và dịch vụ tiền sảnh. Chỗ nghỉ cung cấp lễ tân 24/24, dịch vụ đưa đón sân bay, bếp chung và Wi-Fi miễn phí ở toàn bộ chỗ nghỉ.\n\nKhách sạn sẽ cung cấp cho khách các phòng được trang bị điều hòa có bàn làm việc, ấm đun nước, tủ lạnh, lò nướng, két an toàn, TV màn hình phẳng và phòng tắm riêng với vòi xịt/chậu rửa vệ sinh. Tại Sunrise Hanoi Hotel, các phòng đều đi kèm với ga trải giường và khăn tắm.\n\nKhách có thể thưởng thức bữa sáng thực đơn buffet, kiểu Á hoặc món chay tại chỗ nghỉ.\n\nChỗ nghỉ cách Tràng Tiền Plaza 2.6 km và Nhà hát múa rối Thăng Long 3.2 km.\nGía là 450000.0\nĐiểm đánh giá của nó là 8.48\n'
# Out:
# '\nmô tả của khách sạn:\nTọa lạc ở Hà Nội, cách Bảo tàng dân tộc học Việt Nam 1.8 km, Nam Cường X Hotel cung cấp chỗ nghỉ có phòng chờ chung, chỗ đậu xe riêng miễn phí, sân hiên và quầy bar. Khách sạn 3 sao này có dịch vụ phòng và dịch vụ tiền sảnh. Chỗ nghỉ cung cấp lễ tân 24/24, dịch vụ đưa đón sân bay, bếp chung và Wi-Fi miễn phí ở toàn bộ chỗ nghỉ.\n\nTại khách sạn, phòng nào cũng có điều hòa, khu vực ghế ngồi, TV màn hình phẳng có truyền hình vệ tinh, két an toàn, phòng tắm riêng, vòi xịt/chậu rửa vệ sinh, đồ vệ sinh cá nhân miễn phí và máy sấy tóc. Các phòng đều có ấm đun nước, trong đó một số phòng có ban công và một số khác thì nhìn ra thành phố. Tại Nam Cường X Hotel, các phòng được thiết kế có ga trải giường và khăn tắm.\n\nTại chỗ nghỉ, khách có thể sử dụng bể sục.\n\nNam Cường X Hotel cách Trung tâm thương mại Vincom Nguyễn Chí Thanh 3.6 km và Sân vận động Quốc gia Mỹ Đình 4.1 km.\nGía là 360000.0\nĐiểm đánh giá của nó là 8.38\n'

# %%
from openai import OpenAI
import os


def get_embedding(text: str) -> list:
    response = client.embeddings.create(
        input=text,
        model="text-embedding-3-small"
    )
    return response.data[0].embedding
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 1. Lấy embedding cho truy vấn
query = '\nmô tả của khách sạn:\nNằm ở Hà Nội, cách Nhà hát Lớn Hà Nội 2.2 km, Sunrise Hanoi Hotel cung cấp chỗ nghỉ có phòng chờ chung, chỗ đậu xe riêng miễn phí, sân hiên và nhà hàng. Khách sạn 3 sao này có dịch vụ phòng và dịch vụ tiền sảnh. Chỗ nghỉ cung cấp lễ tân 24/24, dịch vụ đưa đón sân bay, bếp chung và Wi-Fi miễn phí ở toàn bộ chỗ nghỉ.\n\nKhách sạn sẽ cung cấp cho khách các phòng được trang bị điều hòa có bàn làm việc, ấm đun nước, tủ lạnh, lò nướng, két an toàn, TV màn hình phẳng và phòng tắm riêng với vòi xịt/chậu rửa vệ sinh. Tại Sunrise Hanoi Hotel, các phòng đều đi kèm với ga trải giường và khăn tắm.\n\nKhách có thể thưởng thức bữa sáng thực đơn buffet, kiểu Á hoặc món chay tại chỗ nghỉ.\n\nChỗ nghỉ cách Tràng Tiền Plaza 2.6 km và Nhà hát múa rối Thăng Long 3.2 km.\nGía là 450000.0\nĐiểm đánh giá của nó là 8.48\n'
query_embedding = np.array(get_embedding(query)).reshape(1, -1)

# 2. Tính độ tương đồng cosine với từng khách sạn
df['similarity'] = df['context_embedding'].apply(lambda x: 
    cosine_similarity(np.array(x).reshape(1, -1), query_embedding)[0][0]
)

# 3. Lấy top-k khách sạn gợi ý
top_k = df.sort_values(by='similarity', ascending=False).head(10)
print(top_k[['name', 'description', 'similarity']])
# Out:
#                                                  name  \
# 35                                Sunrise Hanoi Hotel
# 38                                 Luxury Hanoi Hotel
# 30                                  Nam Cường X Hotel
# 31                                La Dolce Vita Hotel
# 37                                     Majestik Hotel
# 34                            Hi.Home House near Lake
# 32  Apartment 1BR-FL24th-R105 Building-Vinhomes Oc...
# 33  Apartment 1BR-FL22th-R103 Building-Vinhome Oce...
# 39                              22Land Moon West Lake
# 36                                 Era Cozy Apartment
#
#                                           description  similarity
# 35  Nằm ở Hà Nội, cách Nhà hát Lớn Hà Nội 2.2 km...    0.997893
# 38  Nằm ở Hà Nội, cách Bảo tàng dân tộc học Việt...    0.816344
# 30  Tọa lạc ở Hà Nội, cách Bảo tàng dân tộc học ...    0.803647
# 31  La Dolce Vita Hotel có trung tâm thể dục, phòn...    0.767149
# 37  Nằm ở Hà Nội, cách Sân vận động Quốc gia Mỹ ...    0.764469
# 34  Tọa lạc ở Hà Nội, cách Trung tâm thương mại ...    0.728535
# 32  Nằm ở Hà Nội, cách Trung tâm mua sắm AEON MA...    0.715565
# 33  Tọa lạc ở Hà Nội, cách Trung tâm mua sắm AEO...    0.707693
# 39  Nằm ở Hà Nội, 22Land Moon West Lake nhìn ra ...    0.699414
# 36  Tọa lạc ở Hà Nội, cách Trung tâm thương mại ...    0.678891

# %%
import numpy as np
import ast

# Chuyển string -> list -> array
embedding = np.array(df['context_embedding'][2])
print(embedding.shape)
# Out:
# (1536,)

# %%
df['context_embedding'][1]
# Out:
# [0.02112189680337906,
#  0.028038524091243744,
#  0.002571346238255501,
#  -0.04794794321060181,
#  0.03218574821949005,
#  -0.056490395218133926,
#  0.004016329068690538,
#  0.020901445299386978,
#  -0.02340906858444214,
#  -0.006093384698033333,
#  0.04488919675350189,
#  0.014866618439555168,
#  -0.021094340831041336,
#  -0.023422846570611,
#  0.021273456513881683,
#  -0.018035592511296272,
#  0.020171204581856728,
#  -0.01399170607328415,
#  0.0007931044674478471,
#  0.04552299156785011,
#  0.05665573105216026,
#  0.020873889327049255,
#  0.03339822217822075,
#  -0.005662817507982254,
#  0.005848822649568319,
#  -0.025021111592650414,
#  -0.011497861705720425,
#  0.03028436191380024,
#  0.026522928848862648,
#  -0.039929065853357315,
#  -0.02863098494708538,
#  -0.038771700114011765,
#  0.016382213681936264,
#  -0.025958025828003883,
#  0.0389370359480381,
#  -0.006027938332408667,
#  -0.012393441051244736,
#  0.023147283121943474,
#  -0.024483762681484222,
#  -0.021907251328229904,
#  -0.028658540919423103,
#  -0.02164546586573124,
#  0.009927153587341309,
#  0.024304646998643875,
#  -0.013254575431346893,
#  0.013909037224948406,
#  -0.08812501281499863,
#  -0.03422491252422333,
#  0.01937207207083702,
#  0.027418509125709534,
#  0.005018689204007387,
#  -0.030449699610471725,
#  -0.0013950371649116278,
#  0.051695600152015686,
#  0.05880512297153473,
#  0.06111985072493553,
#  -0.011125852353870869,
#  0.016203097999095917,
#  0.003088026773184538,
#  0.003489315276965499,
#  0.0058143772184848785,
#  -0.04114153981208801,
#  0.005149581469595432,
#  -0.01056094840168953,
#  -0.043566495180130005,
#  -0.012896344065666199,
#  -0.009210689924657345,
#  0.05748242139816284,
#  -0.004123109858483076,
#  0.028245197609066963,
#  0.027969634160399437,
#  0.01514218095690012,
#  -0.06811914592981339,
#  0.011787203140556812,
#  0.03474847972393036,
#  0.007419531233608723,
#  -0.032103076577186584,
#  -0.039488162845373154,
#  0.0076675377786159515,
#  0.02664693258702755,
#  0.008018880151212215,
#  0.03728365898132324,
#  -0.037752117961645126,
#  -0.05731708183884621,
#  -0.019854307174682617,
#  -0.003063915064558387,
#  -0.03623652085661888,
#  0.04497186467051506,
#  0.01624443382024765,
#  -0.05031778663396835,
#  -0.07131567597389221,
#  0.013867703266441822,
#  -0.012489888817071915,
#  0.0953998789191246,
#  -0.00455712154507637,
#  0.008859347552061081,
#  -0.011745868250727654,
#  -0.08514893800020218,
#  -0.0067375130020082,
#  0.020777443423867226,
#  0.011380747891962528,
#  -0.022747717797756195,
#  0.03433513641357422,
#  -0.041058871895074844,
#  -0.008053326047956944,
#  0.008831790648400784,
#  -0.022651270031929016,
#  -0.011876760981976986,
#  -0.005146136973053217,
#  0.006923517677932978,
#  -0.010436944663524628,
#  -0.041802890598773956,
#  -0.02175569161772728,
#  0.016519995406270027,
#  0.014811505563557148,
#  -0.014343048445880413,
#  0.0016129041323438287,
#  -0.01916540041565895,
#  -0.030256805941462517,
#  -0.051695600152015686,
#  0.0038268796633929014,
#  0.03896459564566612,
#  -0.013771255500614643,
#  -0.07561445981264114,
#  -0.00874223280698061,
#  0.013847035355865955,
#  -0.06431637704372406,
#  -0.047203924506902695,
#  -0.006227721460163593,
#  -0.010381831787526608,
#  0.037614334374666214,
#  -0.03246130794286728,
#  0.015996426343917847,
#  -0.0013760922010987997,
#  -0.03802768141031265,
#  0.01883472502231598,
#  -0.016809336841106415,
#  0.051557816565036774,
#  -0.07743317633867264,
#  -0.006251833401620388,
#  0.016602665185928345,
#  -0.003232697257772088,
#  -0.014205267652869225,
#  0.04786527529358864,
#  -0.05067601799964905,
#  0.002424953505396843,
#  -0.04378694295883179,
#  0.019923197105526924,
#  0.02893410436809063,
#  0.028878992423415184,
#  -0.004123109858483076,
#  0.04381450265645981,
#  -0.024635322391986847,
#  -0.05343164503574371,
#  -0.023491736501455307,
#  -0.02728072740137577,
#  -0.012200547382235527,
#  -0.0004346574132796377,
#  -0.008514893241226673,
#  0.0027039609849452972,
#  0.0046432348899543285,
#  -0.05246717482805252,
#  0.042629580944776535,
#  -0.056490395218133926,
#  0.00016146263806149364,
#  0.01737423986196518,
#  -0.028686096891760826,
#  -0.007757095620036125,
#  -0.046046558767557144,
#  0.01654755137860775,
#  -0.04406250640749931,
#  -0.026054471731185913,
#  -0.02322995290160179,
#  0.010423166677355766,
#  -0.017842696979641914,
#  -0.004729348234832287,
#  -0.013530137948691845,
#  -0.00905913021415472,
#  -0.04122421145439148,
#  -0.003747655311599374,
#  0.016726667061448097,
#  0.04447585344314575,
#  -0.010381831787526608,
#  0.020680995658040047,
#  0.006499839946627617,
#  -0.026784714311361313,
#  0.011697645299136639,
#  0.030119024217128754,
#  -0.0018893281230702996,
#  -0.047507043927907944,
#  0.0014734003925696015,
#  0.01369547564536333,
#  0.04447585344314575,
#  0.03135905787348747,
#  0.033673785626888275,
#  -0.016823114827275276,
#  0.010498946532607079,
#  -0.020846333354711533,
#  0.06431637704372406,
#  0.00994093157351017,
#  0.017966700717806816,
#  0.02123212069272995,
#  0.010285384953022003,
#  0.0010548891732469201,
#  -0.028603428974747658,
#  -0.015335075557231903,
#  -0.04207845404744148,
#  0.02267882600426674,
#  0.019303180277347565,
#  -0.01461861189454794,
#  0.024717992171645164,
#  -0.018986282870173454,
#  -0.0018566050566732883,
#  -0.007874209433794022,
#  0.0017791029531508684,
#  0.04094864800572395,
#  0.049601320177316666,
#  -0.030449699610471725,
#  -0.02715672366321087,
#  -0.017016008496284485,
#  3.07586306007579e-05,
#  -0.001394176040776074,
#  0.09694302827119827,
#  0.007254193536937237,
#  -0.002512789098545909,
#  0.020212538540363312,
#  0.025145115330815315,
#  -0.011015626601874828,
#  -0.01926184631884098,
#  -0.03912993147969246,
#  0.02121834270656109,
#  0.005380365531891584,
#  -0.017663581296801567,
#  -0.027142945677042007,
#  0.006854627281427383,
#  0.06701689958572388,
#  -0.02779051847755909,
#  -0.020997893065214157,
#  -0.013144350610673428,
#  -0.01957874372601509,
#  -0.04249179735779762,
#  -0.016809336841106415,
#  0.005091024562716484,
#  0.012889454141259193,
#  -0.03739388659596443,
#  -0.00817732885479927,
#  0.015348853543400764,
#  -0.03535471856594086,
#  0.015128402970731258,
#  0.031634621322155,
#  0.02475932613015175,
#  -0.010388721711933613,
#  0.004770682659000158,
#  -0.039102375507354736,
#  -0.004185111727565527,
#  -0.012262549251317978,
#  0.018986282870173454,
#  0.059797149151563644,
#  0.01895872689783573,
#  -0.024800660088658333,
#  -0.03213063254952431,
#  -0.00734375137835741,
#  -0.021080560982227325,
#  0.005311474669724703,
#  0.0063965036533772945,
#  -0.009031574241816998,
#  0.014122598804533482,
#  0.02653670683503151,
#  0.011408303864300251,
#  -0.016575109213590622,
#  -0.022031253203749657,
#  0.005442367400974035,
#  0.04739682003855705,
#  0.017360461875796318,
#  -0.07765362411737442,
#  0.005070357117801905,
#  0.036594752222299576,
#  0.02496599778532982,
#  -0.015417744405567646,
#  0.07175657898187637,
#  -0.09446296095848083,
#  -0.03510671481490135,
#  -0.008880014531314373,
#  0.029182111844420433,
#  -0.03736633062362671,
#  -0.014522165060043335,
#  0.06078917533159256,
#  -0.013778144493699074,
#  0.06161586567759514,
#  0.0012546723010018468,
#  0.0380827933549881,
#  0.017512021586298943,
#  0.03111105039715767,
#  -0.00027039609267376363,
#  0.05935624986886978,
#  0.013034124858677387,
#  -0.020667217671871185,
#  -0.03452803194522858,
#  0.048967525362968445,
#  0.002531734062358737,
#  0.0672924593091011,
#  0.023188617080450058,
#  0.013833257369697094,
#  0.012489888817071915,
#  -0.06453683227300644,
#  0.06332435458898544,
#  0.00670995656400919,
#  0.026688266545534134,
#  0.0013881480554118752,
#  -0.04651501774787903,
#  -0.02185213752090931,
#  0.0270740557461977,
#  0.014921731315553188,
#  -0.0024025640450417995,
#  -0.029815904796123505,
#  0.02185213752090931,
#  0.011945651844143867,
#  0.060734063386917114,
#  -0.045137204229831696,
#  -0.08625118434429169,
#  0.0022923387587070465,
#  -0.001887605874799192,
#  0.042739804834127426,
#  -0.06244255229830742,
#  0.02362951822578907,
#  0.011993874795734882,
#  -0.010664284229278564,
#  0.039818838238716125,
#  -0.013778144493699074,
#  -0.03510671481490135,
#  -0.03235108405351639,
#  -0.02435976080596447,
#  -0.015955092385411263,
#  -0.004960132297128439,
#  0.0474519319832325,
#  -0.01978541538119316,
#  -0.04863684996962547,
#  -0.006406837608665228,
#  -0.011056961491703987,
#  -0.006079606246203184,
#  -0.01025093998759985,
#  -0.030532369390130043,
#  -0.018889836966991425,
#  0.024180645123124123,
#  -0.01643732748925686,
#  -0.02091522328555584,
#  -0.014728836715221405,
#  0.04048018902540207,
#  0.03507915884256363,
#  0.019964532926678658,
#  0.03563028201460838,
#  0.002512789098545909,
#  -0.0009102186886593699,
#  0.029953686520457268,
#  -0.00699929753318429,
#  -0.038881924003362656,
#  0.04389717057347298,
#  -0.0022337818518280983,
#  -0.04152732715010643,
#  0.010409388691186905,
#  -0.06690666824579239,
#  0.01967519149184227,
#  0.008590673096477985,
#  0.01883472502231598,
#  0.03957083076238632,
#  -0.02466288022696972,
#  0.00642750458791852,
#  -0.03959839046001434,
#  -0.04155488684773445,
#  -0.040039289742708206,
#  0.015844866633415222,
#  -0.03587828949093819,
#  -0.02683982625603676,
#  -0.0006841709837317467,
#  -0.040645528584718704,
#  -0.00873534381389618,
#  0.023050837218761444,
#  0.015886200591921806,
#  -0.001215060125105083,
#  -0.0013915926683694124,
#  -0.024814439937472343,
#  0.018972504884004593,
#  0.016065316274762154,
#  -0.017222682014107704,
#  0.007102633826434612,
#  0.0019237734377384186,
#  0.019000062718987465,
#  0.00885245855897665,
#  0.033894237130880356,
#  -0.008893792517483234,
#  0.019124064594507217,
#  -0.033784013241529465,
#  -0.02353307232260704,
#  -0.013502581976354122,
#  -0.0026264588814228773,
#  0.029016774147748947,
#  0.04535765200853348,
#  0.053459201008081436,
#  0.03381156921386719,
#  -0.018462713807821274,
#  -0.005249473266303539,
#  -0.012269438244402409,
#  -0.000793535029515624,
#  -0.0034531475976109505,
#  -0.008349555544555187,
#  -0.029595455154776573,
#  -0.010416277684271336,
#  -0.006368947681039572,
#  0.03946060687303543,
#  -0.015844866633415222,
#  -0.008728454820811749,
#  -0.04406250640749931,
#  0.046983473002910614,
#  0.009079797193408012,
#  0.04378694295883179,
#  -0.01233832910656929,
#  0.006551507860422134,
#  0.0011306690284982324,
#  -0.005387254524976015,
#  0.06282833963632584,
#  -0.051695600152015686,
#  -0.015073291026055813,
#  -0.04296025633811951,
#  0.002933022566139698,
#  -0.0360160693526268,
#  -0.00572826387360692,
#  -0.005748930852860212,
#  -0.02736339531838894,
#  0.026178475469350815,
#  -0.03695298358798027,
#  -0.036181408911943436,
#  0.026412703096866608,
#  -0.048857301473617554,
#  0.039295271039009094,
#  -0.036594752222299576,
#  -0.05946647375822067,
#  0.04706614464521408,
#  0.029953686520457268,
#  -0.021783247590065002,
#  0.011752757243812084,
#  0.004746570717543364,
#  0.009500031359493732,
#  0.06128519028425217,
#  0.003227530512958765,
#  -0.04932576045393944,
#  -0.00790865533053875,
#  -0.03932282701134682,
#  -0.004595011472702026,
#  -0.01665777713060379,
#  -0.03698053956031799,
#  -0.005910824052989483,
#  0.02124589867889881,
#  0.0008645785856060684,
#  -0.03306754678487778,
#  0.04723148047924042,
#  0.0053838100284338,
#  0.05665573105216026,
#  0.023657074198126793,
#  0.005686929449439049,
#  0.013137461617588997,
#  -0.026467816904187202,
#  0.049601320177316666,
#  -0.004729348234832287,
#  0.015417744405567646,
#  0.04092109203338623,
#  -0.01000293344259262,
#  -0.010402499698102474,
#  0.045963890850543976,
#  0.004312559496611357,
#  -0.013137461617588997,
#  -0.021590353921055794,
#  0.02604069374501705,
#  0.028796322643756866,
#  0.04568832740187645,
#  -0.0512271411716938,
#  -0.019702747464179993,
#  -0.027955856174230576,
#  -0.04778260737657547,
#  -0.02520022727549076,
#  -0.07192191481590271,
#  -0.008618230000138283,
#  -0.009231356903910637,
#  -0.021466350182890892,
#  0.010912290774285793,
#  -0.001863494049757719,
#  0.13623829185962677,
#  0.009472474455833435,
#  -0.03061503730714321,
#  -0.006248388905078173,
#  -0.025641128420829773,
#  0.011642532423138618,
#  -0.0015758753288537264,
#  0.008728454820811749,
#  -0.016395991668105125,
#  0.01623065397143364,
#  -0.008308221586048603,
#  -0.03323288634419441,
#  -0.013089237734675407,
#  0.012469220906496048,
#  -0.05797843262553215,
#  0.051888495683670044,
#  -0.027418509125709534,
#  -0.028768766671419144,
#  0.034610699862241745,
#  0.01979919523000717,
#  0.04841640219092369,
#  0.0023130059707909822,
#  -0.03822057321667671,
#  -0.02830030955374241,
#  -0.011222299188375473,
#  -0.0310283824801445,
#  0.028355421498417854,
#  -0.023064615204930305,
#  0.003468648064881563,
#  -0.012793007306754589,
#  0.008184217847883701,
#  -0.013922815211117268,
#  0.031083494424819946,
#  -0.017966700717806816,
#  -0.01139452587813139,
#  -0.006279389373958111,
#  0.003671875689178705,
#  -0.01935829408466816,
#  -0.04227134957909584,
#  0.011573641560971737,
#  -0.03422491252422333,
#  -0.009279580786824226,
#  -0.07230770587921143,
#  -0.014301714487373829,
#  -0.05056579038500786,
#  0.02467665821313858,
#  0.01482528354972601,
#  -0.013750588521361351,
#  0.01602398231625557,
#  -0.02310594916343689,
#  0.002972634742036462,
#  -0.0018548828084021807,
#  0.009252023883163929,
#  0.010078713297843933,
#  0.005273585207760334,
#  0.030146582052111626,
#  0.010333608835935593,
#  -0.03684275969862938,
#  0.02923722378909588,
#  0.002647126093506813,
#  0.04235401749610901,
#  0.01843515783548355,
#  -0.020887667313218117,
#  -0.003799323458224535,
#  0.016065316274762154,
#  -0.01322701945900917,
#  -0.043676719069480896,
#  0.013860814273357391,
#  -0.013599028810858727,
#  0.02593046799302101,
#  0.004987688269466162,
#  0.01831115409731865,
#  -0.0045502325519919395,
#  0.004364227410405874,
#  -0.014384383335709572,
#  -0.002457676688209176,
#  0.011277412064373493,
#  0.027721628546714783,
#  -0.040755752474069595,
#  -0.028066081926226616,
#  0.01082962192595005,
#  0.004915353376418352,
#  -0.028493203222751617,
#  0.03020169399678707,
#  -0.043125592172145844,
#  -0.012386552058160305,
#  0.021797025576233864,
#  0.008570006117224693,
#  0.0028486314695328474,
#  0.002617847640067339,
#  -0.02278905175626278,
#  0.0036064295563846827,
#  0.03717343509197235,
#  -0.027955856174230576,
#  -0.0071784136816859245,
#  0.01686444878578186,
#  0.01632710173726082,
#  -0.020336542278528214,
#  -0.017043564468622208,
#  0.019344516098499298,
#  -0.021783247590065002,
#  0.025544680655002594,
#  0.01233832910656929,
#  -0.027859408408403397,
#  0.006413726601749659,
#  0.02830030955374241,
#  0.036374304443597794,
#  0.0009171077981591225,
#  0.02010231278836727,
#  -0.0003190501593053341,
#  0.03838591277599335,
#  0.00941736251115799,
#  -8.261504990514368e-05,
#  -0.05006977915763855,
#  -0.022348150610923767,
#  -0.007825986482203007,
#  0.0024094530381262302,
#  0.017760029062628746,
#  0.019399628043174744,
#  0.02934744954109192,
#  0.03392179310321808,
#  0.02736339531838894,
#  -0.0011969762854278088,
#  -0.011862982995808125,
#  -0.006551507860422134,
#  -0.005542258732020855,
#  0.03499648720026016,
#  -0.0298710186034441,
#  -0.004701791796833277,
#  -0.07065432518720627,
#  -0.006816737353801727,
#  -0.006685844622552395,
#  0.0093691386282444,
#  0.030890600755810738,
#  0.025365564972162247,
#  -0.03802768141031265,
#  0.006337946746498346,
#  0.02362951822578907,
#  0.017636025324463844,
#  -0.02509000152349472,
#  0.0395432747900486,
#  -0.022031253203749657,
#  -0.03946060687303543,
#  0.02696382999420166,
#  0.0036615419667214155,
#  -0.013805701397359371,
#  0.014205267652869225,
#  0.00556637067347765,
#  -0.021728133782744408,
#  -0.0696071907877922,
#  -0.01572086289525032,
#  0.04717636853456497,
#  -0.028878992423415184,
#  -0.021714355796575546,
#  -0.024704214185476303,
#  -0.0022096699103713036,
#  0.025751352310180664,
#  0.034307580441236496,
#  -0.022210368886590004,
#  0.02863098494708538,
#  -0.001534540904685855,
#  0.002259615808725357,
#  -0.0008826624252833426,
#  0.002676404546946287,
#  -0.021879693493247032,
#  -0.023891303688287735,
#  0.01603776030242443,
#  0.026784714311361313,
#  -0.01591375656425953,
#  0.01107762847095728,
#  -0.027556288987398148,
#  -0.04756215587258339,
#  -0.02791452221572399,
#  0.02832786552608013,
#  -0.04924308881163597,
#  0.01602398231625557,
#  -0.004188556224107742,
#  0.01654755137860775,
#  -0.046046558767557144,
#  -0.0031517506577074528,
#  0.05497479811310768,
#  -0.002623014384880662,
#  -0.02591669000685215,
#  -0.030890600755810738,
#  -0.0009257190977223217,
#  -0.04665279760956764,
#  0.04395228251814842,
#  -0.011897427961230278,
#  -0.03113860823214054,
#  0.007688204757869244,
#  -0.030063912272453308,
#  -0.0025282895658165216,
#  0.004254002124071121,
#  -0.019082730636000633,
#  0.023546850308775902,
#  -0.002960579004138708,
#  -0.02404286339879036,
#  -0.01667155511677265,
#  -0.021907251328229904,
#  -0.007839764468371868,
#  0.017939144745469093,
#  0.042106010019779205,
#  -0.01572086289525032,
#  0.014894174411892891,
#  0.0020460544619709253,
#  -0.0023216174449771643,
#  -0.02132856845855713,
#  0.04078330844640732,
#  -0.0008508004248142242,
#  -0.010120047256350517,
#  0.005690373945981264,
#  0.01667155511677265,
#  -0.004949798807501793,
#  0.001185781555250287,
#  0.03811034932732582,
#  0.0019582188688218594,
#  -0.004188556224107742,
#  -0.007977546192705631,
#  -0.019840529188513756,
#  -0.009045352227985859,
#  -0.008211774751543999,
#  0.006052050273865461,
#  0.016395991668105125,
#  0.023450402542948723,
#  -0.004174777772277594,
#  0.013123682700097561,
#  0.00023315205180551857,
#  -0.0052976966835558414,
#  0.015624416060745716,
#  -0.014301714487373829,
#  -0.0007573674083687365,
#  -0.004650123883038759,
#  -0.0031913628336042166,
#  -0.021177008748054504,
#  0.030063912272453308,
#  -0.00957581028342247,
#  -0.03080793283879757,
#  0.023960193619132042,
#  -0.010808954946696758,
#  -0.012166102416813374,
#  -0.02593046799302101,
#  0.006331057753413916,
#  0.006413726601749659,
#  -0.005531925242394209,
#  0.020212538540363312,
#  0.02915455400943756,
#  -0.007075077388435602,
#  0.01635465770959854,
#  0.00658250879496336,
#  0.03207552060484886,
#  0.049711547791957855,
#  -0.06056872382760048,
#  -0.008549339137971401,
#  -0.003561650402843952,
#  -0.020529435947537422,
#  -0.006258722394704819,
#  -0.0474519319832325,
#  0.03488626331090927,
#  0.04692836105823517,
#  0.003422146663069725,
#  0.03466581180691719,
#  -0.008604451082646847,
#  0.017443131655454636,
#  -0.0348035953938961,
#  -0.046046558767557144,
#  -0.057923320680856705,
#  0.010416277684271336,
#  0.022637492045760155,
#  -0.016271989792585373,
#  -0.023450402542948723,
#  -0.0418580025434494,
#  -0.009768704883754253,
#  -0.06420615315437317,
#  -0.025751352310180664,
#  -0.013185684569180012,
#  0.05031778663396835,
#  0.038248129189014435,
#  0.018173372372984886,
#  -0.014163932763040066,
#  -0.020680995658040047,
#  -0.009651590138673782,
#  0.016850670799613,
#  -0.026164697483181953,
#  0.019179178401827812,
#  0.03342577815055847,
#  0.010540280491113663,
#  -0.05384499207139015,
#  0.026357591152191162,
#  0.020474324002861977,
#  0.02008853480219841,
#  -0.025999359786510468,
#  -0.03780722990632057,
#  -0.007109522819519043,
#  -0.008067104034125805,
#  0.028066081926226616,
#  0.01854538358747959,
#  0.002096000360324979,
#  -0.020143648609519005,
#  -0.010113158263266087,
#  0.013957261107861996,
#  -0.022017475217580795,
#  -0.0031672511249780655,
#  0.018696943297982216,
#  -0.008011991158127785,
#  -0.004639790393412113,
#  -0.011532307602465153,
#  -0.01822848618030548,
#  -0.00020484226115513593,
#  -0.028796322643756866,
#  0.029071886092424393,
#  -0.016203097999095917,
#  -0.0028417424764484167,
#  -0.06596975773572922,
#  0.01583108864724636,
#  0.026467816904187202,
#  -0.006134719122201204,
#  -0.025241561233997345,
#  0.014604833908379078,
#  0.041802890598773956,
#  0.055746372789144516,
#  0.007199080660939217,
#  -0.041582442820072174,
#  0.005738597363233566,
#  0.02362951822578907,
#  -0.02311972714960575,
#  0.007612424902617931,
#  0.019110286608338356,
#  -0.0025489567779004574,
#  0.014604833908379078,
#  0.009293358772993088,
#  -0.013729921542108059,
#  -0.015872422605752945,
#  0.0007203386630862951,
#  0.013578361831605434,
#  -0.01234521809965372,
#  0.005745486356317997,
#  -0.017746251076459885,
#  -0.007584868930280209,
#  -0.026908716186881065,
#  0.05549836903810501,
#  -2.9063273814244894e-06,
#  0.0006036550039425492,
#  0.008335777558386326,
#  0.01139452587813139,
#  -0.018462713807821274,
#  0.0018962172325700521,
#  0.013447469100356102,
#  -0.009954709559679031,
#  0.008108437992632389,
#  0.00974114891141653,
#  0.022113922983407974,
#  0.027418509125709534,
#  -0.023367734625935555,
#  -0.009438029490411282,
#  -0.003857880597934127,
#  0.01915162056684494,
#  0.008411557413637638,
#  0.05266007035970688,
#  0.05629749968647957,
#  0.014012373052537441,
#  0.00932091474533081,
#  0.007791541051119566,
#  0.006816737353801727,
#  -0.027005163952708244,
#  0.019909419119358063,
#  -0.033039990812540054,
#  -0.014894174411892891,
#  0.03587828949093819,
#  0.01461861189454794,
#  0.014205267652869225,
#  -0.0053149196319282055,
#  -0.017718695104122162,
#  -0.007143968250602484,
#  -0.0070681883953511715,
#  -0.01426037959754467,
#  -0.04025974124670029,
#  -0.008494226261973381,
#  -0.006034827325493097,
#  0.005473367869853973,
#  -0.01625821180641651,
#  -0.0339493490755558,
#  0.022334372624754906,
#  -0.01348880399018526,
#  0.04020462557673454,
#  0.02112189680337906,
#  0.03193774074316025,
#  -0.019606299698352814,
#  -0.054396115243434906,
#  0.004767238162457943,
#  0.011628754436969757,
#  0.009279580786824226,
#  0.029843462631106377,
#  0.05447878688573837,
#  0.0040542189963161945,
#  0.0019151621963828802,
#  0.016079094260931015,
#  0.007247304078191519,
#  0.012510555796325207,
#  -0.027514955028891563,
#  -0.016850670799613,
#  -0.016285767778754234,
#  0.0004899852792732418,
#  0.025778908282518387,
#  -0.01667155511677265,
#  -0.025654906406998634,
#  0.01676800288259983,
#  -0.0029898574575781822,
#  0.006434393581002951,
#  -0.01654755137860775,
#  -0.0006174331065267324,
#  -0.01738801971077919,
#  0.006379281170666218,
#  0.009444918483495712,
#  0.024538876488804817,
#  0.0009351915796287358,
#  -0.0177049171179533,
#  -0.0412517674267292,
#  -0.006124385632574558,
#  -0.00019267875177320093,
#  -0.005766153801232576,
#  -0.010795176960527897,
#  -0.003547872416675091,
#  -0.015596860088407993,
#  -0.0035547614097595215,
#  -0.019399628043174744,
#  -0.022031253203749657,
#  0.026798492297530174,
#  0.047920387238264084,
#  -0.018779611214995384,
#  -0.01643732748925686,
#  0.016795558854937553,
#  -0.041472215205430984,
#  -0.029898574575781822,
#  0.0614505261182785,
#  -0.00015048317436594516,
#  -0.0216592438519001,
#  0.0033360333181917667,
#  -0.001103973831050098,
#  0.001413121004588902,
#  0.00011560724669834599,
#  0.04059041664004326,
#  0.007956878282129765,
#  0.02091522328555584,
#  0.02893410436809063,
#  -0.014604833908379078,
#  -0.015872422605752945,
#  -0.014329270459711552,
#  -0.01545907836407423,
#  0.009651590138673782,
#  -0.027570068836212158,
#  -0.028658540919423103,
#  0.005177137907594442,
#  0.0035254829563200474,
#  0.0008434808114543557,
#  -0.03422491252422333,
#  -0.013013457879424095,
#  -0.025875356048345566,
#  0.030780375003814697,
#  -0.0045502325519919395,
#  -0.00757109047845006,
#  -0.014535943046212196,
#  0.036704979836940765,
#  0.002468010177835822,
#  -0.013888370245695114,
#  -0.008122216910123825,
#  -0.010795176960527897,
#  -0.019964532926678658,
#  0.017415575683116913,
#  -0.011112074367702007,
#  -0.005903935059905052,
#  -0.00043250457383692265,
#  0.059190910309553146,
#  0.023588184267282486,
#  0.0134750260040164,
#  0.007812208030372858,
#  -0.007240415085107088,
#  -0.02583402208983898,
#  -0.007495310623198748,
#  -0.012193658389151096,
#  -0.005218472331762314,
#  -0.0020305542275309563,
#  0.012269438244402409,
#  0.01051272451877594,
#  0.04442073777318001,
#  0.03072526305913925,
#  -0.04081086441874504,
#  0.005576704163104296,
#  0.025007333606481552,
#  0.01726401597261429,
#  0.002023665001615882,
#  -0.023753521963953972,
#  -0.003881992306560278,
#  0.005965936928987503,
#  -0.01087095681577921,
#  -0.018187152221798897,
#  0.04254691302776337,
#  0.03218574821949005,
#  -0.0037786562461405993,
#  0.032626647502183914,
#  -0.00911424309015274,
#  0.023450402542948723,
#  0.026398925110697746,
#  -0.009906486608088017,
#  0.017925366759300232,
#  0.014591055922210217,
#  0.007002742029726505,
#  0.018779611214995384,
#  -0.0036512084770947695,
#  -0.019275624305009842,
#  0.00879734568297863,
#  0.00528391869738698,
#  -0.027735406532883644,
#  -0.050758685916662216,
#  0.020997893065214157,
#  -0.008976461365818977,
#  ...]

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key="pcsk_5suXtf_Uo6g1vjUUitGSPRcwSmUuPR2YT7t7eCaU93BUxDr78f6ACPPngnPFfbwovC2k8G")

# %%
# Tạo index trong Pinecone (nếu chưa có)
index_name = "hotel-recommendations"

# Kiểm tra xem index đã tồn tại chưa
if index_name not in pc.list_indexes():
    pc.create_index(index_name, dimension=768, metric="cosine")  # Đảm bảo dimension đúng với kích thước embedding của bạn

# %%
# Khởi tạo kết nối với Pinecone
index = pc.Index(index_name)

# Lấy dữ liệu từ DataFrame
for idx, row in df.iterrows():
    # Lấy embedding và context
    embedding = row['context_embedding']  # Đây là vector embedding bạn đã tính toán
    context = row['context']  # Đây là mô tả văn bản của khách sạn

    # Tạo metadata cho context (có thể chứa tên khách sạn, giá, địa điểm...)
    metadata = {
        "name": row["name"],
        "price": row["price"],
        "rating": row["rating"],
        "location": row["location"],
        "description": row["description"]
    }

    # Insert vào Pinecone
    index.upsert(
        [(str(idx), embedding, metadata)]  # Lưu trữ với ID duy nhất
    )

print("Data inserted into Pinecone successfully.")

# %%
# Tìm kiếm N khách sạn tương tự
query_embedding = df['context_embedding'].iloc[0]  # Ví dụ, lấy embedding của khách sạn đầu tiên

# Truy vấn Pinecone để tìm các khách sạn tương tự
result = index.query(query_embedding, top_k=5, include_metadata=True)

# In ra kết quả
for match in result['matches']:
    print(f"Hotel: {match['metadata']['name']}, Price: {match['metadata']['price']}, Rating: {match['metadata']['rating']}")

# %%
index_name = 'semantic-search-fast'

# Check if index already exists (it shouldn't if this is first time running the demo)
if not pc.has_index(name=index_name):
    # If does not exist, create index
    pc.create_index(
        name=index_name,
        dimension=384, # dimensionality of MiniLM
        metric='cosine',
        spec = ServerlessSpec(
            cloud='aws', 
            region='us-east-1'
        )
    )

# Initialize index client
index = pc.Index(name=index_name)

# View index stats
index.describe_index_stats()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 index_name = 'semantic-search-fast'
#       3 # Check if index already exists (it shouldn't if this is first time running the demo)
# ----> 4 if not pc.has_index(name=index_name):
#       5     # If does not exist, create index
#       6     pc.create_index(
#       7         name=index_name,
#       8         dimension=384, # dimensionality of MiniLM
#    (...)
#      13         )
#      14     )
#      16 # Initialize index client
#
# NameError: name 'pc' is not defined

# %%
from tqdm import tqdm

batch_size = 100

for start in tqdm(range(0, len(dataset.documents), batch_size), "Upserting records batch"):
    batch = dataset.documents.iloc[start:start + batch_size].to_dict(orient="records")
    index.upsert(vectors=batch)

# %%
df['context'][0]
# Out:
# '\nĐây là mô tả của khách sạn:\nNằm tại vị trí thuận tiện ở trung tâm Hà Nội, NT Elysian hotel cung cấp các phòng điều hòa với Wi-Fi miễn phí, chỗ đậu xe riêng miễn phí và dịch vụ phòng. Khách sạn 3 sao này có quầy lễ tân 24 giờ và máy ATM. Khách có thể sử dụng khu vườn.\n\nTất cả các căn được trang bị TV màn hình phẳng có truyền hình vệ tinh, tủ lạnh, ấm đun nước, vòi xịt/chậu rửa vệ sinh, đồ vệ sinh cá nhân miễn phí và bàn làm việc. Với phòng tắm riêng được trang bị vòi sen và máy sấy tóc, một số căn tại khách sạn cũng có view thành phố. Tại NT Elysian hotel, tất cả các phòng đều được thiết kế có ga trải giường và khăn tắm.\n\nCác điểm tham quan nổi tiếng gần chỗ nghỉ bao gồm Ô Quan Chưởng, Nhà hát múa rối Thăng Long và Hồ Hoàn Kiếm. Sân bay Quốc tế Nội Bài cách 23 km, đồng thời chỗ nghỉ có cung cấp dịch vụ đưa đón sân bay mất phí.\nGía của nó là 744480.0\nĐiểm đánh giá của nó là 9.39\n'

# %%
df

# %%
# !pwd
# Out:
# /Users/doa_ai/Developer/Grab-project/ai/model/src
