# %%
import asyncio
from playwright.async_api import async_playwright

async def crawl_pasgo_by_page(keyword, max_pages=5):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        all_results = []

        for page_num in range(1, max_pages + 1):
            url = f"https://pasgo.vn/tim-kiem?search={keyword}&page={page_num}"
            print(f"🔎 Crawling page {page_num}: {url}")
            await page.goto(url)
            try:
                await page.wait_for_selector("div.item-child-info a", timeout=8000)
            except:
                print(f"⛔ Không tìm thấy dữ liệu ở trang {page_num}")
                continue

            items = await page.query_selector_all("div.item-child-info a")
            for item in items:
                name = await item.inner_text()
                link = await item.get_attribute("href")
                full_link = f"https://pasgo.vn{link}"
                print(f"{name.strip()} - {full_link}")
                all_results.append((name.strip(), full_link))

        await browser.close()
        return all_results

# Ví dụ: Crawl 5 trang kết quả cho từ khoá "lẩu"
results = await crawl_pasgo_by_page("lẩu", max_pages=5)
# Out:
# 🔎 Crawling page 1: https://pasgo.vn/tim-kiem?search=lẩu&page=1
# Lộc-ally - Cát Linh
#
# Tầng 2, Khách Sạn Grand Mercure Hanoi, Số 9 Cát Linh, P. Quốc Tử Giám,Q. Ba Đình
#
# Đặt bàn giữ chỗ
# Buffet Món Việt, Gọi món Á - Âu - https://pasgo.vnhttps://pasgo.vn/nha-hang/loc-ally-restaurant-cat-linh-5490
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/5490?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# GoGi House - Giang Văn Minh
#
# Số 14 Giang Văn Minh, P. Kim Mã, Q. Ba Đình
#
# Đặt bàn giữ chỗ
# Gọi món, Buffet Nướng Lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/gogi-house-giang-van-minh-5575
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/5575?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Lẩu Nấm Ashima - Giang Văn Minh
#
# Số 60 Giang Văn Minh, P. Đội Cấn, Q. Ba Đình
#
# Ưu đãi hấp dẫn
# Gọi món Á, Chuyên Lẩu Nấm - https://pasgo.vnhttps://pasgo.vn/nha-hang/nha-hang-lau-nam-ashima-giang-van-minh-963
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/963?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Bò Ngon 555 – Núi Trúc
#
# Ngõ 12, Phố Núi Trúc, 105-C8 Giảng Võ, Q. Đống Đa
#
# Giảm 10%
# Chuyên lẩu bò nhúng dấm - https://pasgo.vnhttps://pasgo.vn/nha-hang/bo-ngon-555-ngo-12-nui-truc-1369
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/1369?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# GoGi House - Quán Sứ
#
# Số 30 - 32 Phố Quán Sứ, P. Hàng Bông, Q. Hoàn Kiếm
#
# Đặt bàn giữ chỗ
# Gọi món, Buffet Nướng Lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/gogi-house-quan-su-5577
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/5577?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Yukssam BBQ – Ô Chợ Dừa
#
# Số 43 Ô Chợ Dừa, Q. Đống Đa
#
# Đặt bàn giữ chỗ
# Gọi món, buffet nướng lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/yukssam-bbq-o-cho-dua-1286
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/1286?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Lẩu Đức Trọc - Trần Huy Liệu
#
# Số 101 D1 Trần Huy Liệu, P. Giảng Võ, Q. Ba Đình
#
# Giảm tới 10%
# Gọi Món Việt (Chuyên lẩu) - https://pasgo.vnhttps://pasgo.vn/nha-hang/lau-duc-troc-tran-huy-lieu-3744
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/3744?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Lẩu Hơi Cosmos - Giảng Võ
#
# Tòa nhà D2 Giảng Võ, Q. Ba Đình
#
# Giảm 10%
# Gọi món lẩu hơi - https://pasgo.vnhttps://pasgo.vn/nha-hang/nha-hang-lau-hoi-cosmos-giang-vo-2102
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/2102?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Hugo BBQ - Đê La Thành
#
# Số 295 Đê La Thành, Q. Đống Đa
#
# Ưu đãi hấp dẫn
# Buffet Nướng Lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/hugo-bbq-de-la-thanh-4913
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/4913?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Dainty Hotpot - Đê La Thành
#
# 295 Đê La Thành, P. Chợ Dừa, Q. Đống Đa
#
# Giảm 10%
# Buffet Lẩu - https://pasgo.vnhttps://pasgo.vn/nha-hang/nha-hang-dainty-hotpot---de-la-thanh-5143
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/5143?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# Chai Talay - Xã Đàn
#
# 474 Xã Đàn, P. Nam Đồng, Q. Đống Đa
#
# Đặt bàn giữ chỗ
#
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/4917?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=5
# Hugo BBQ - Lạc Long Quân
#
# Số 153-155 Lạc Long Quân, Q. Tây Hồ
#
# Ưu đãi hấp dẫn
# Buffet Nướng Lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/hugo-bbq-lac-long-quan-4915
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/4915?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=5
# Shang Chi - Trung Hòa
#
# Số 84 Trung Hòa, P. Trung Hòa, Q. Cầu Giấy
#
# Đi 4 tính tiền 3
# Buffet Lẩu băng chuyền Đài Loan - https://pasgo.vnhttps://pasgo.vn/nha-hang/nha-hang-shang-chi-lau-dai-loan-bang-chuyen-sieu-toc-trung-hoa-4685
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/4685?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=5
# GoGi House - Nguyễn Khánh Toàn
#
# Số 162 Nguyễn Khánh Toàn, P. Quan Hoa, Q. Cầu Giấy
#
# Đặt bàn giữ chỗ
# Gọi món, Buffet Nướng Lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/gogi-house-nguyen-khanh-toan-5581
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/5581?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=5
# Bò Nhúng Dấm 555 - Trung Hòa
#
# 52 Trung Hòa, Q. Cầu Giấy
#
# Giảm 10%
# Chuyên lẩu bò nhúng dấm - https://pasgo.vnhttps://pasgo.vn/nha-hang/bo-nhung-dam-555-trung-hoa---phut-sum-vay-ben-noi-lau-919
# Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/919?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=5

# %%
import pandas as pd
import glob
import os

def merge_csv_files(folder_path, output_file):
    # Lấy danh sách tất cả file .csv trong folder
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

    # Đọc và nối tất cả các file
    df_list = [pd.read_csv(file) for file in csv_files]
    merged_df = pd.concat(df_list, ignore_index=True)

    # Lưu ra file mới
    merged_df.to_csv(output_file, index=False)
    print(f"✅ Đã merge {len(csv_files)} file vào {output_file}")

# Ví dụ sử dụng
merge_csv_files("/Users/doa_ai/Developer/Grab-project/ai/crawl/crawl_pasgo/data", "merged_output.csv")
# Out:
# ✅ Đã merge 63 file vào merged_output.csv

# %%
import asyncio
from playwright.async_api import async_playwright

async def crawl_pasgo_by_city(keyword, city_id=2, max_pages=3):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await p.chromium.launch_persistent_context(
            user_data_dir="/tmp/playwright",  # cache tạm
            headless=True
        )

        # Gán cityId ngay từ đầu bằng add_init_script
        await context.add_init_script(f"""
            localStorage.setItem('cityId', '{city_id}');
        """)

        page = await context.new_page()
        all_results = []

        for page_num in range(1, max_pages + 1):
            url = f"https://pasgo.vn/tim-kiem?search={keyword}&page={page_num}"
            print(f"🔎 Crawling page {page_num}: {url}")
            await page.goto(url, wait_until="load")

            try:
                await page.wait_for_selector("div.item-child-info a", timeout=8000)
            except:
                print(f"⛔ Trang {page_num} không có kết quả")
                continue

            items = await page.query_selector_all("div.item-child-info a")
            for item in items:
                name = await item.inner_text()
                link = await item.get_attribute("href")
                full_url = f"https://pasgo.vn{link}"
                print(f"📍 {name.strip()} - {full_url}")
                all_results.append((name.strip(), full_url))

        await browser.close()
        return all_results

# Hồ Chí Minh = city_id 2
results = await crawl_pasgo_by_city("lẩu", city_id=2, max_pages=2)
# Out:
# 🔎 Crawling page 1: https://pasgo.vn/tim-kiem?search=lẩu&page=1
# 📍 Lộc-ally - Cát Linh
#
# Tầng 2, Khách Sạn Grand Mercure Hanoi, Số 9 Cát Linh, P. Quốc Tử Giám,Q. Ba Đình
#
# Đặt bàn giữ chỗ
# Buffet Món Việt, Gọi món Á - Âu - https://pasgo.vnhttps://pasgo.vn/nha-hang/loc-ally-restaurant-cat-linh-5490
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/5490?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=1
# 📍 GoGi House - Giang Văn Minh
#
# Số 14 Giang Văn Minh, P. Kim Mã, Q. Ba Đình
#
# Đặt bàn giữ chỗ
# Gọi món, Buffet Nướng Lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/gogi-house
Q. Ba Đình
#
# Đặt bàn giữ chỗ
# Gọi món, Buffet Lẩu Đài Loan - https://pasgo.vnhttps://pasgo.vn/nha-hang/nha-hang-manwah-lotte-dao-tan-4706
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/4706?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2
# 📍 Izakaya Yancha - Triệu Việt Vương
#
# 121 Triệu Việt Vương, Q. Hai Bà Trưng
#
# Giảm 10%
# Gọi món Nhật Bản - https://pasgo.vnhttps://pasgo.vn/nha-hang/nha-hang-izakaya-yancha-trieu-viet-vuong-2165
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/2165?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2
# 📍 Bếp Thái Koh Yam - Thái Hà
#
# Số 330 Thái Hà, P. Láng Hạ, Q. Đống Đa
#
# Đi 4 tính tiền 3
# Buffet Lẩu, Gọi món Thái Lan - https://pasgo.vnhttps://pasgo.vn/nha-hang/bep-thai-koh-yam-thai-ha-2683
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/2683?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2
# 📍 CityFood - Láng Hạ
#
# Số 87 Láng Hạ, P.Thành Công, Q. Ba Đình
#
# Đặt bàn giữ chỗ
# Gọi món Á, Buffet Lẩu - https://pasgo.vnhttps://pasgo.vn/nha-hang/nha-hang-cityfood-rap-chieu-phim-quoc-gia-4367
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/4367?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2
# 📍 Bếp Thái Koh Yam - Bà Triệu
#
# Số 3, ngõ Bà Triệu, P. Lê Đại Hành, Q.Hai Bà Trưng
#
# Đi 4 tính tiền 3
# Buffet Lẩu, Gọi món Thái Lan - https://pasgo.vnhttps://pasgo.vn/nha-hang/bep-thai-koh-yam-ba-trieu-3876
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/3876?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2
# 📍 GoGi House - Bùi Thị Xuân
#
# Số 151 Bùi Thị Xuân, P. Bùi Thị Xuân, Q. Hai Bà Trưng
#
# Đặt bàn giữ chỗ
# Gọi món, Buffet Nướng Lẩu Hàn Quốc - https://pasgo.vnhttps://pasgo.vn/nha-hang/gogi-house-bui-thi-xuan-5574
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/5574?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2
# 📍 Lẩu Cua Đồng Hòa Lạc - Triệu Việt Vương
#
# Số 90 Đường Triệu Việt Vương, P.Bùi Thị Xuân, Q. Hai Bà Trưng
#
# Đặt bàn giữ chỗ
# Hải sản tươi sống( Chuyên cua) - https://pasgo.vnhttps://pasgo.vn/nha-hang/lau-cua-dong-hoa-lac-trieu-viet-vuong-4642
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/4642?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2
# 📍 Lẩu Tôm Sen Đào - Phó Đức Chính
#
# 36 Phó Đức Chính, P. Trúc Bạch, Q. Ba Đình
#
# Đặt bàn giữ chỗ
# Gọi món Việt - https://pasgo.vnhttps://pasgo.vn/nha-hang/lau-tom-sen-dao-pho-duc-chinh-3976
# 📍 Đặt chỗ - https://pasgo.vnhttps://pasgo.vn/dat-cho-ngay/3976?returnUrl=/tim-kiem?search=l%E1%BA%A9u&page=2

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from playwright.async_api import async_playwright

import re

async def extract_price_range(page):
    # Tìm span chứa giá trung bình
    info_span = await page.query_selector("span.pasgo-giatrungbinh")
    if not info_span:
        return {"price_range": ""}

    full_text = await info_span.inner_text()
    
    match = re.search(r"(\d{1,3}(?:\.\d{3})*)\s*-\s*(\d{1,3}(?:\.\d{3})*)", full_text)
    price_range = f"{match.group(1)} - {match.group(2)} đ/người" if match else ""


    return {"price_range": price_range}

def slug_to_name(slug):
    words = slug.split("-")
    return " ".join([word for word in words])
async def extract_summary(article):
    result = {}
    result['description'] = ''
    titles = await article.query_selector_all(".txt-title")
    for title in titles:
        title_text = (await title.inner_text()).strip().replace(":", "").upper()

        if "MÓN ĐẶC SẮC" in title_text:
            span = await article.query_selector("span")
            value = (await span.inner_text()).strip() if span else ""
            result['cuisines'] = value
        elif "ĐIỂM ĐẶC TRƯNG" in title_text:
            ps_texts = []
            sibling = await title.evaluate_handle("el => el.nextElementSibling")
            while sibling:
                is_null = await sibling.evaluate("el => el === null")
                if is_null:
                    break
                tag_name = await sibling.evaluate("el => el.tagName")
                if tag_name == "DIV":
                    class_name = await sibling.get_attribute("class")
                    if class_name == "txt-title":
                        break  # gặp title tiếp theo → dừng
                if tag_name == "P":
                    ps_texts.append((await sibling.inner_text()).strip())
                sibling = await sibling.evaluate_handle("el => el.nextElementSibling")
            value = "\n".join(ps_texts)
            result['description'] += value

        else:
            sibling = await title.evaluate_handle("el => el.nextElementSibling")
            value = ""
            if sibling:
                is_null = await sibling.evaluate("el => el === null")
                if not is_null:
                    tag_name = await sibling.evaluate("el => el.tagName")
                    if tag_name == "DIV" and await sibling.get_attribute("class") == "text-description":
                        value = (await sibling.inner_text()).strip()
                    elif tag_name == "P":
                        value = (await sibling.inner_text()).strip()
            result['description'] += value

    print("result: ", result['description'])
    return result

async def extract_image_gallery(article):
    image_urls = []
    images = await article.query_selector_all("img")
    for image in images:
        src = await image.get_attribute("src")
        if src:
            if src.startswith("/"):
                src = f"https://pasgo.vn{src}"
            image_urls.append(src)
    print("image_urls_2: ", image_urls)
    return image_urls


 

async def get_detail_data(page, detail_link):
    await page.goto(detail_link)
    await page.wait_for_load_state("domcontentloaded")

    articles = await page.query_selector_all("article")
    result= {}
    result['photo_url'] = []
    for article in articles:
        article_id = await article.get_attribute("id")
        if article_id == "NH-TOMTAT":
            result.update(await extract_summary(article))
        if article_id == "info-booth":
            result.update(await extract_price_range(article))
            print(await extract_price_range(article))
        if article_id == "NH-ANH":
            result['photo_url'].extend(await extract_image_gallery(article))
    return result


async def crawl_pasgo_by_page(category_slug, max_pages=5):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        all_results = []
        for page_num in range(1, max_pages + 1):
            url = f"https://pasgo.vn/ha-noi/nha-hang{category_slug}?page={page_num}"
            print(f"🔎 Crawling page {page_num}: {url}")
            await page.goto(url)
            try:
                await page.wait_for_selector("div.wapitem a", timeout=8000)
            except:
                print(f"⛔ Không tìm thấy dữ liệu ở trang {page_num}")
                continue

            items = await page.query_selector_all("div.wapitem")
            for item in items:
                result = {}
                main = await item.query_selector("div.waptop-main")
                desc = await item.query_selector("div.waptop-desc")
                
                link = await item.query_selector("a.waptop")
                link = await link.get_attribute("href")
                full_link = f"https://pasgo.vn{link}" if link.startswith("/") else link
                detail_page = await browser.new_page()
                detail_data = await get_detail_data(detail_page, full_link)
                result.update(detail_data)
                await detail_page.close()

                img = await main.query_selector("a.waptop img")
                img_url = await img.get_attribute("src") if img else None
                result['photo_url'].extend(img_url)
                name = await main.query_selector("div.wapfooter h3")
                name = await name.inner_text() if name else "Không có tên"

                address = await main.query_selector("p")
                address = await address.inner_text() if address else "Không có địa chỉ"


                sale = await desc.query_selector("div.wapsale")
                sale = await sale.inner_text() if sale else "Không có sale"

                tag = await desc.query_selector("div.waptag")
                tag = await tag.inner_text() if tag else "Không có tag"

                result.update({
                    "img_url": img_url,
                    "name": name.strip(),
                    "address": address.strip(),
                    "link": full_link
                })
                result['city'] = slug_to_name(city)
                all_results.append(result)

        await browser.close()
        return all_results

# Chạy thử
if __name__ == "__main__":
    categories = ["","/lau-27", "/buffet-29", "/hai-san-28", "/lau-and-nuong-91", "/quan-nhau-165", "/mon-chay-44", "/dat-tiec-224", "/han-quoc-16", "/nhat-ban-15", "/mon-au-23", "/mon-viet-21", "/mon-thai-18", "/mon-trung-hoa-126", "/tiec-cuoi-143"]
    cities = [
    "ha-noi",
    "ho-chi-minh",
    "hai-phong",
    "da-nang",
    "khanh-hoa",
    "can-tho",
    "vung-tau",
    "bac-giang",
    "bac-ninh",
    "binh-duong",
    "binh-dinh",
    "binh-thuan",
    "hung-yen",
    "kien-giang",
    "lam-dong",
    "nghe-an",
    "quang-nam",
    "quang-ninh",
    "thanh-hoa",
    "thua-thien-hue"
    ]
    for city in cities:
        for cat in categories:
            asyncio.run(crawl_pasgo_by_page(cat, max_pages=5))
# Out:
# 🔎 Crawling page 1: https://pasgo.vn/ha-noi/nha-hang?page=1
# {'price_range': '150.000 - 250.000 đ/người'}
# result:  Cặp đôi, gia đình, khách văn phòng, sinh nhật...- Ấm cúng, nhẹ nhàng
#
# - Sức chứa: 40 Khách- Xe ô tô: Để xe trước cửa nhà hàng (Miễn phí)
#
# - Xe máy: Để xe trước cửa nhà hàng (Miễn phí)- Tại Botanica, các đầu bếp rất có tâm với nghề, và đã từng làm cho các khách sạn 5 sao tại Việt Nam và quốc tế, rất am hiểu về chế biến món ăn mang phong cách Âu để đảm bảo các món ăn chất lượng luôn được trọn vị.
# - Bánh mỳ home-made riêng của hệ thống: đặc ruột thơm ngậy bơ luôn là món ưa thích suốt gần 10 năm nay khi khách hàng thưởng thức cùng với Bít tết và các món nướng khác.
# - Nhà hàng luôn sử dụng những nguyên liệu tươi sạch để chế biến các món ăn.
# image_urls_2:  ['https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-botanica-giang-vo-1-normal-269735056374.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-botanica---9-normal-2697351269582.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-botanica---5-normal-2697351469584.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-botanica---17-normal-2697351669586.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/thiet-ke-chua-co-ten-normal-2701817469796.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-botanica-giang-vo-2-normal-210589376375.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-botanica-giang-vo-3-normal-210589436376.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-botanica-giang-vo-4-normal-210589446377.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-botanica-giang-vo-5-normal-210589456378.webp']
# {'price_range': '438.000 - 488.000 đ/người'}
# result:  Đặt tiệc, liên hoan, gia đình, bạn bè, sinh nhật...- Sang trọng, hiện đại
#
# - Sức chứa: 1000 khách (04 tầng)
#
# - Phòng riêng: 03 phòng (18 khách/phòng)- Xe ô tô: Để xe cách nhà hàng từ 30m trở lên (Phí phụ thuộc đơn vị trông giữ xe)
#
# - Xe máy: Để xe gần nhà hàng (Miễn phí)
# image_urls_2:  ['https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-1-normal-1472695945698.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-2-normal-1907799245699.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-3-normal-1468051045700.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-4-normal-1468051845701.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-5-normal-1467852245702.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-6-normal-1468053645703.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-7-normal-1907783045704.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-8-normal-1467852745705.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-bay-seafood-buffet-ho-guom-9-normal-1467853045706.webp']
# {'price_range': '150.000 - 250.000 đ/người'}
# result:  Cặp đôi, Gia đình, Khách văn phòng, Tiếp khách, Sinh nhật...Kiến trúc châu Âu cổ điển, thanh lịch.
#
# - Sức chứa: 100 Khách (03 tầng)
#
# - Phòng riêng: 02 phòng (12 khách/phòng)- Xe ô tô: Để xe trước cửa nhà hàng (Phí phụ thuộc đơn vị trông giữ xe)
#
# - Xe máy: Để xe trước cửa nhà hàng (Miễn phí)
# image_urls_2:  ['https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---9-normal-2697345369572.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---2-normal-2697345469573.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---3-normal-2697346769574.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---8-normal-2697346869575.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---4-normal-2697347069577.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---5-normal-2697347169578.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---6-normal-2697347369580.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/slide-grill6-haonam---10-normal-2697347469581.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-grille6-hao-nam-1-normal-210591965517.webp']
# {'price_range': ''}
# result:  Tụ họp, sinh nhật, liên hoan, gia đình,...- Phong cách Thái
#
# - Sức chứa: 96 Khách.- Ô tô:Bãi xe gần nhà hàng (Phí phụ thuộc vào đơn vị trông giữ xe)
#
# - Xe máy: Trước cửa nhà hàng (Miễn phí)
#
# ĐIỂM ĐẶC TRƯNG:
# image_urls_2:  ['https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-1-normal-844383310003.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-2-normal-844384210004.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-3-normal-844384710005.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-4-normal-844385210006.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-5-normal-844385410007.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-6-normal-844385910008.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-7-normal-844386510009.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-8-normal-844386610010.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-chai-talay-xa-dan-9-normal-844386710011.webp']
# {'price_range': '95.000 - 395.000 đ/người'}
# result:  Tiếp khách, đặt tiệc, giao lưu gia đình, hẹn hò lãng mạnKhông gian phương Tây hiện đại, sang trọng, ấm cúng. Sức chứa: 150 ngườiCó
# image_urls_2:  ['https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-22-normal-82806867582.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-31-normal-82806917583.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-17-normal-82806927584.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-19-normal-82807007585.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-18-normal-82806987586.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-23-normal-82807047587.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-24-normal-82807107588.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-26-normal-828071737650.webp', 'https://pasgo.vn/Upload/anh-chi-tiet/nha-hang-alfresco-4-normal-828072237651.webp']

# %%
import pandas as pd
import glob
import os

df = pd.read_csv("/Users/doa_ai/Developer/Grab-project/ai/crawl/crawl_pasgo/merged_output.csv")

# %%
import pandas as pd

def align_csv_to_template(file_a, file_b, output_file):
    # Đọc file A và file B
    df_a = pd.read_csv(file_a)
    df_b = pd.read_csv(file_b)

    # Lấy danh sách cột mẫu từ B
    template_columns = df_b.columns.tolist()

    # Chỉ giữ các cột có trong B
    df_a_aligned = df_a.reindex(columns=template_columns)

    # Lưu kết quả ra file mới
    df_a_aligned.to_csv(output_file, index=False)
    print(f"✅ File đã chuẩn hóa và lưu vào {output_file}")

# Ví dụ sử dụng
align_csv_to_template("/Users/doa_ai/Developer/Grab-project/ai/crawl/crawl_pasgo/merged_output.csv", "/Users/doa_ai/Developer/Grab-project/ai/model/src/data/fnb_processed.csv", "/Users/doa_ai/Developer/Grab-project/ai/crawl/crawl_pasgo/merged_output_aligned.csv")
# Out:
# ✅ File đã chuẩn hóa và lưu vào /Users/doa_ai/Developer/Grab-project/ai/crawl/crawl_pasgo/merged_output_aligned.csv

# %%
df = pd.read_csv("/Users/doa_ai/Developer/Grab-project/ai/crawl/crawl_pasgo/merged_output_aligned.csv")
df['city'] = df['city'].str.replace(' ', '')

# %%
df.to_csv("/Users/doa_ai/Developer/Grab-project/ai/crawl/crawl_pasgo/food_pasgo.csv", index=False)

# %%
df = pd
